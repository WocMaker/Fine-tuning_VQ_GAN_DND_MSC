# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
from PIL import BmpImageFile
import imghdr
import os
import re
import codecs
import sys
general_path = "/content/drive/MyDrive/classfolder_renamed"
folder_list = os.listdir(general_path)
for foldername in folder_list:
    path= general_path + "/" + foldername
    old_names = os.listdir(path)  # 取路径下的文件名，生成列表
    count_img=1
    for old_name in old_names:  # 遍历列表下的文件名
        delpath=path+"/"+old_name
    try:
        img = Image.open(delpath)
        img = BmpImageFile.open(delpath)
    except:
        # os.remove(delpath)
        print("delete"+str(old_name))
    print("finish folder"+str(foldername))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-e92f5ac98140> in <module>()
#       1 from PIL import Image
# ----> 2 from PIL import BmpImageFile
#       3 import imghdr
#       4 import os
#       5 import re
#
# ImportError: cannot import name 'BmpImageFile' from 'PIL' (/usr/local/lib/python3.7/dist-packages/PIL/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
